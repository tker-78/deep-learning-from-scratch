# %% [markdown]
# # Test Scripts

# %%
import pandas as pd
import matplotlib.pylab as plt
import numpy as np

# %%
x = np.arange(0, 20, 0.1)

# %%
def function_1(x):
    return x**2

# %%
y = function_1(x)

# %%
y
# Out:
# array([0.0000e+00, 1.0000e-02, 4.0000e-02, 9.0000e-02, 1.6000e-01,
#        2.5000e-01, 3.6000e-01, 4.9000e-01, 6.4000e-01, 8.1000e-01,
#        1.0000e+00, 1.2100e+00, 1.4400e+00, 1.6900e+00, 1.9600e+00,
#        2.2500e+00, 2.5600e+00, 2.8900e+00, 3.2400e+00, 3.6100e+00,
#        4.0000e+00, 4.4100e+00, 4.8400e+00, 5.2900e+00, 5.7600e+00,
#        6.2500e+00, 6.7600e+00, 7.2900e+00, 7.8400e+00, 8.4100e+00,
#        9.0000e+00, 9.6100e+00, 1.0240e+01, 1.0890e+01, 1.1560e+01,
#        1.2250e+01, 1.2960e+01, 1.3690e+01, 1.4440e+01, 1.5210e+01,
#        1.6000e+01, 1.6810e+01, 1.7640e+01, 1.8490e+01, 1.9360e+01,
#        2.0250e+01, 2.1160e+01, 2.2090e+01, 2.3040e+01, 2.4010e+01,
#        2.5000e+01, 2.6010e+01, 2.7040e+01, 2.8090e+01, 2.9160e+01,
#        3.0250e+01, 3.1360e+01, 3.2490e+01, 3.3640e+01, 3.4810e+01,
#        3.6000e+01, 3.7210e+01, 3.8440e+01, 3.9690e+01, 4.0960e+01,
#        4.2250e+01, 4.3560e+01, 4.4890e+01, 4.6240e+01, 4.7610e+01,
# ...

# %%
graph = plt.plot(x ,y)

# %%
h = 1e-4

# %%
print(h)
# Out:
# 0.0001
